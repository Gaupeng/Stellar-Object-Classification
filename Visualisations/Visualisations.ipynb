# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd
import matplotlib.lines as mlines

# %%
dataSet = pd.read_csv('../ANN/tanH/accuracy_0.001_24.csv')

# %%
plt.plot(dataSet['Training Data'], dataSet['Accuracy'])
plt.xlabel("Training Data Size")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
dataSetKNN = pd.read_csv("../KNN/clustersize.csv")

# %%
plt.plot(dataSetKNN['Cluster Size'], dataSetKNN['Accuracy'])
plt.xlabel("K")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
dataSetDT = pd.read_csv("../DTrees_RF/DT_depth_accuracy.csv")

# %%
plt.plot(dataSetDT['Depth'], dataSetDT['Accuracy'])
plt.xlabel("Depth")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
dataSetRF = pd.read_csv('../DTrees_RF/RF_accuracy.csv')

# %%
plt.plot(dataSetRF['#Trees'], dataSetRF['Accuracy'])
plt.xlabel("No. of Trees")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
dataSetANN2 = pd.read_csv("../ANN/sigmoid/accuracy_0.7_32.csv")

# %%
plt.plot(dataSetANN2['Training Data'], dataSetANN2['Accuracy'])
plt.xlabel("Training Data Size")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(dataSetANN2['Training Data'], dataSetANN2['Accuracy'], label = "Sigmoid", color = "blue")
plt.plot(dataSetANN2['Training Data'], dataSet['Accuracy'], color = "red", label = "tanh")
plt.xlabel("Training Data Size")
plt.ylabel("Accuracy")
blue_line = mlines.Line2D([], [], color='blue',
                          markersize=15, label='sigmoid')
red_line = mlines.Line2D([], [], color='red',
                          markersize=15, label='tanh')
plt.legend(handles=[blue_line, red_line])
plt.title("tanh v/s Sigmoid")
plt.show()
